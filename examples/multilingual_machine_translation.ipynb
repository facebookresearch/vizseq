# %%
from glob import glob
root = 'data/multilingual_translation_ted58_x_en_test'
src = sorted(glob(f'{root}/src_*.*'))
ref = glob(f'{root}/ref_*.txt')
hypo = glob(f'{root}/pred_*.txt')
tag = glob(f'{root}/tag_*.txt')

# %%
import vizseq

# %%
vizseq.view_stats(src, ref)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/css/bootstrap.min.css"
#           integrity="sha384-GJzZqFGwb1QTTN6wy59ffF1BuGJpLSa9DkKMp0DgiMDm4iYMj70gZWKYbI706tWS" crossorigin="anonymous">
#
#     <style>
#         body {
#             padding-top: 60px; /* 60px to make the container go all the way to the bottom of the topbar */
#         }
#     </style>
# </head>
#
# <body>
#
# <div class="container-fluid">
#     <div class="row">
#         <table class="table table-hover table-bordered">
#             <thead class="thead-light">
#             <tr>
#                 <th scope="col"></th>
#                 <th scope="col">Type</th>
#                 <th scope="col">Examples</th>
#                 <th scope="col">Tokens / Frames</th>
#                 <th scope="col">Chars / Duration (ms)</th>
#             </tr>
#             </thead>
#             <tbody id="statsTable">
#
#             <tr>
#                 <th scope="row">Source 0</th>
#                 <td>Text</td>
#                 <td>165,426</td>
#                 <td>2,762,862</td>
#                 <td>14,007,635</td>
#             </tr>
#
#
#             <tr>
#                 <th scope="row">Reference 0</th>
#                 <td> Text </td>
#                 <td>165,426</td>
#                 <td>3,255,567</td>
#                 <td>15,488,762</td>
#             </tr>
#
#             </tbody>
#         </table>
#     </div>
# </div>
#
# <script src="https://code.jquery.com/jquery-3.3.1.slim.min.js"
#         integrity="sha384-q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+8abtTE1Pi6jizo" crossorigin="anonymous">
# </script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.6/umd/popper.min.js"
#         integrity="sha384-wHAiFfRlMFy6i5SRaxvfOCifBUQy1xHdJ/yoi7FRNXMRBu5WHdZYu1hA6ZOblgut" crossorigin="anonymous">
# </script>
# <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/js/bootstrap.min.js"
#         integrity="sha384-B0UglyR+jN6CkvvICOB2joaf5I4l3gm9GU6Hc1og6Ls7i6U/mkkaduKaBhlAXv9k" crossorigin="anonymous">
# </script>
#
# </body>
# </html>

# %%
vizseq.view_n_grams(src, k=10)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/css/bootstrap.min.css"
#           integrity="sha384-GJzZqFGwb1QTTN6wy59ffF1BuGJpLSa9DkKMp0DgiMDm4iYMj70gZWKYbI706tWS" crossorigin="anonymous">
#     <script src="https://kit.fontawesome.com/3c563f9647.js"></script>
#
#     <style>
#         body {
#             padding-top: 60px; /* 60px to make the container go all the way to the bottom of the topbar */
#         }
#     </style>
# </head>
#
# <body>
#
#
# <div class="container">
#     <div class="row">
#
#         <div class="col">
#             <table class="table table-hover table-sm table-bordered text-center">
#                 <thead class="thead-light">
#                 <tr><th scope="col">1-gram</th><th scope="col">Count</th></tr>
#                 </thead>
#                 <tbody>
#
#                 <tr><td>,</td><td>145159</td></tr>
#
#                 <tr><td>.</td><td>140099</td></tr>
#
#                 <tr><td>&#34;</td><td>32162</td></tr>
#
#                 <tr><td>de</td><td>20545</td></tr>
#
#                 <tr><td>a</td><td>17600</td></tr>
#
#                 <tr><td>่</td><td>15606</td></tr>
#
#                 <tr><td>်</td><td>14085</td></tr>
#
#                 <tr><td>?</td><td>12986</td></tr>
#
#                 <tr><td>)</td><td>11946</td></tr>
#
#                 <tr><td>(</td><td>11940</td></tr>
#
#                 </tbody>
#             </table>
#         </div>
#
#         <div class="col">
#             <table class="table table-hover table-sm table-bordered text-center">
#                 <thead class="thead-light">
#                 <tr><th scope="col">2-gram</th><th scope="col">Count</th></tr>
#                 </thead>
#                 <tbody>
#
#                 <tr><td>&#34; &#34;</td><td>15085</td></tr>
#
#                 <tr><td>. &#34;</td><td>2626</td></tr>
#
#                 <tr><td>: &#34;</td><td>2087</td></tr>
#
#                 <tr><td>. (</td><td>2027</td></tr>
#
#                 <tr><td>, a</td><td>1757</td></tr>
#
#                 <tr><td>, &#34;</td><td>1632</td></tr>
#
#                 <tr><td>, hogy</td><td>1332</td></tr>
#
#                 <tr><td>, e</td><td>1286</td></tr>
#
#                 <tr><td>de la</td><td>1184</td></tr>
#
#                 <tr><td>&#34; .</td><td>1152</td></tr>
#
#                 </tbody>
#             </table>
#         </div>
#
#         <div class="col">
#             <table class="table table-hover table-sm table-bordered text-center">
#                 <thead class="thead-light">
#                 <tr><th scope="col">3-gram</th><th scope="col">Count</th></tr>
#                 </thead>
#                 <tbody>
#
#                 <tr><td>. &#34; &#34;</td><td>2148</td></tr>
#
#                 <tr><td>: &#34; &#34;</td><td>1805</td></tr>
#
#                 <tr><td>, &#34; &#34;</td><td>1449</td></tr>
#
#                 <tr><td>&#34; &#34; .</td><td>1145</td></tr>
#
#                 <tr><td>? &#34; &#34;</td><td>822</td></tr>
#
#                 <tr><td>&#34; &#34; ,</td><td>546</td></tr>
#
#                 <tr><td>&#34; &#34; (</td><td>406</td></tr>
#
#                 <tr><td>் கள ்</td><td>399</td></tr>
#
#                 <tr><td>่ งที ่</td><td>300</td></tr>
#
#                 <tr><td>( aplausos )</td><td>300</td></tr>
#
#                 </tbody>
#             </table>
#         </div>
#
#         <div class="col">
#             <table class="table table-hover table-sm table-bordered text-center">
#                 <thead class="thead-light">
#                 <tr><th scope="col">4-gram</th><th scope="col">Count</th></tr>
#                 </thead>
#                 <tbody>
#
#                 <tr><td>. &#34; &#34; (</td><td>209</td></tr>
#
#                 <tr><td>ကျွန ် တော ်</td><td>181</td></tr>
#
#                 <tr><td>( מחיאות כפיים )</td><td>121</td></tr>
#
#                 <tr><td>် တော ် တို</td><td>114</td></tr>
#
#                 <tr><td>တော ် တို ့</td><td>113</td></tr>
#
#                 <tr><td>่ า &#34; &#34;</td><td>105</td></tr>
#
#                 <tr><td>ئه ‌ وه ‌</td><td>94</td></tr>
#
#                 <tr><td>&#34; &#34; . (</td><td>93</td></tr>
#
#                 <tr><td>် ပါတယ ် ။</td><td>92</td></tr>
#
#                 <tr><td>( tepuk tangan )</td><td>84</td></tr>
#
#                 </tbody>
#             </table>
#         </div>
#
#     </div>
# </div>
#
#
# <script src="https://code.jquery.com/jquery-3.3.1.slim.min.js"
#         integrity="sha384-q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+8abtTE1Pi6jizo" crossorigin="anonymous">
# </script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.6/umd/popper.min.js"
#         integrity="sha384-wHAiFfRlMFy6i5SRaxvfOCifBUQy1xHdJ/yoi7FRNXMRBu5WHdZYu1hA6ZOblgut" crossorigin="anonymous">
# </script>
# <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/js/bootstrap.min.js"
#         integrity="sha384-B0UglyR+jN6CkvvICOB2joaf5I4l3gm9GU6Hc1og6Ls7i6U/mkkaduKaBhlAXv9k" crossorigin="anonymous">
# </script>
# </body>
# </html>

# %%
vizseq.view_scores(ref, hypo, ['bleu'], tags=tag)
# Out:
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# <ipython-input-6-ee2ec51944db> in <module>
# ----> 1 vizseq.view_scores(ref, hypo, ['bleu'], tags=tag)
#
# ~/Projects/facebookresearch/vizseq/vizseq/ipynb/core.py in view_scores(references, hypothesis, metrics, tags)
#     163                 _hypo.data[i].text, _ref.text, tags=_tags
#     164             ) for i, m in enumerate(models)
# --> 165         } for s in _metrics
#     166     }
#     167
#
# ~/Projects/facebookresearch/vizseq/vizseq/ipynb/core.py in <dictcomp>(.0)
#     163                 _hypo.data[i].text, _ref.text, tags=_tags
#     164             ) for i, m in enumerate(models)
# --> 165         } for s in _metrics
#     166     }
#     167
#
# ~/Projects/facebookresearch/vizseq/vizseq/ipynb/core.py in <dictcomp>(.0)
#     162             m: get_scorer(s)(corpus_level=True, sent_level=False).score(
#     163                 _hypo.data[i].text, _ref.text, tags=_tags
# --> 164             ) for i, m in enumerate(models)
#     165         } for s in _metrics
#     166     }
#
# ~/Projects/facebookresearch/vizseq/vizseq/scorers/bleu.py in score(self, hypothesis, references, tags)
#      97                 pred_slice = [hypothesis[i] for i in indices]
#      98                 group_scores[t] = self.score_corpus_multiprocess(
# ---> 99                     pred_slice, ref_slice
#     100                 )
#     101
#
# ~/Projects/facebookresearch/vizseq/vizseq/scorers/bleu.py in score_corpus_multiprocess(self, hypothesis, references)
#      60                     progress = tqdm(progress)
#      61                 for future in progress:
# ---> 62                     s = future.result()
#      63                     ref_len += s.ref_len
#      64                     sys_len += s.sys_len
#
# ~/miniconda3/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     423                 raise CancelledError()
#     424             elif self._state == FINISHED:
# --> 425                 return self.__get_result()
#     426
#     427             self._condition.wait(timeout)
#
# ~/miniconda3/lib/python3.7/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.

# %%
vizseq.view_examples(src, ref, hypo, ['bleu'], page_sz=2, page_no=16)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/css/bootstrap.min.css"
#           integrity="sha384-GJzZqFGwb1QTTN6wy59ffF1BuGJpLSa9DkKMp0DgiMDm4iYMj70gZWKYbI706tWS" crossorigin="anonymous">
#     <script src="https://kit.fontawesome.com/3c563f9647.js"></script>
#
#     <style>
#         body {
#             padding-top: 60px; /* 60px to make the container go all the way to the bottom of the topbar */
#         }
#     </style>
# </head>
#
# <body>
#
#
# <script>
#     function highlight_span(spanNode, trgSpanId) {
#         trgSpanNode = document.getElementById(trgSpanId);
#         trgSpanNode.style.backgroundColor = '#D6EAF8';
#         spanNode.style.backgroundColor = '#D6EAF8';
#     }
#     function dehighlight_span(spanNode, trgSpanId) {
#         trgSpanNode = document.getElementById(trgSpanId);
#         trgSpanNode.style.backgroundColor = trgSpanNode.parentNode.style.backgroundColor;
#         spanNode.style.backgroundColor = spanNode.parentNode.style.backgroundColor;
#     }
# </script>
#
#
#
# <div class="card">
#     <div class="card-header">
#         <div class="row">
#             <div class="col">
#                 <b># 1 / 2 / 165426 ( 31 / 165426 )</b>
#             </div>
#             <div class="col" align="right">
#             </div>
#         </div>
#     </div>
#     <div class="card-body">
#         <table class="table table-hover table-sm table-borderless">
#             <tbody>
#
#
#             <tr style="background-color:#FDF2E9" id="srcRow00">
#                 <th scope="row">Source 0</th>
#
#                 <td><span id="src_0_0_0">Entro</span> <span id="src_0_0_1">la</span> <span id="src_0_0_2">fine</span> <span id="src_0_0_3">di</span> <span id="src_0_0_4">quest'</span> <span id="src_0_0_5">anno</span> <span id="src_0_0_6">,</span> <span id="src_0_0_7">ci</span> <span id="src_0_0_8">saranno</span> <span id="src_0_0_9">circa</span> <span id="src_0_0_10">un</span> <span id="src_0_0_11">miliardo</span> <span id="src_0_0_12">di</span> <span id="src_0_0_13">persone</span> <span id="src_0_0_14">su</span> <span id="src_0_0_15">questo</span> <span id="src_0_0_16">pianeta</span> <span id="src_0_0_17">che</span> <span id="src_0_0_18">usano</span> <span id="src_0_0_19">attivamente</span> <span id="src_0_0_20">i</span> <span id="src_0_0_21">social</span> <span id="src_0_0_22">network</span> <span id="src_0_0_23">.</span></td>
#
#             </tr>
#
#
#             <tr style="background-color:#EAF2F8">
#
#             </tr>
#
#
#
#
#             <tr style="background-color:#FEF9E7">
#                 <th scope="row">Reference 0</th><td><span id="ref_0_0_0" >By</span> <span id="ref_0_0_1" >the</span> <span id="ref_0_0_2" >end</span> <span id="ref_0_0_3" >of</span> <span id="ref_0_0_4" >this</span> <span id="ref_0_0_5" >year</span> <span id="ref_0_0_6" onmouseover="javascript:highlight_span(this, &quot;src_0_0_6&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;src_0_0_6&quot;)" style="color:#AF601A;font-weight:bold" >,</span> <span id="ref_0_0_7" >there</span> <span id="ref_0_0_8" >'ll</span> <span id="ref_0_0_9" >be</span> <span id="ref_0_0_10" >nearly</span> <span id="ref_0_0_11" >a</span> <span id="ref_0_0_12" >billion</span> <span id="ref_0_0_13" >people</span> <span id="ref_0_0_14" >on</span> <span id="ref_0_0_15" >this</span> <span id="ref_0_0_16" >planet</span> <span id="ref_0_0_17" >that</span> <span id="ref_0_0_18" >actively</span> <span id="ref_0_0_19" >use</span> <span id="ref_0_0_20" onmouseover="javascript:highlight_span(this, &quot;src_0_0_21&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;src_0_0_21&quot;)" style="color:#AF601A;font-weight:bold" >social</span> <span id="ref_0_0_21" >networking</span> <span id="ref_0_0_22" >sites</span> <span id="ref_0_0_23" onmouseover="javascript:highlight_span(this, &quot;src_0_0_23&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;src_0_0_23&quot;)" style="color:#AF601A;font-weight:bold" >.</span></td>
#             </tr>
#
#
#
#
#             <tr><th scope="row">gru_transformer</th><td><span id="hypo_gru_transformer_0_0" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_0&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_0&quot;)" style="color:#1A5276;font-weight:bold" >By</span> <span id="hypo_gru_transformer_0_1" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_1&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_1&quot;)" style="color:#1A5276;font-weight:bold" >the</span> <span id="hypo_gru_transformer_0_2" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_2&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_2&quot;)" style="color:#1A5276;font-weight:bold" >end</span> <span id="hypo_gru_transformer_0_3" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_3&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_3&quot;)" style="color:#1A5276;font-weight:bold" >of</span> <span id="hypo_gru_transformer_0_4" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_4&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_4&quot;)" style="color:#1A5276;font-weight:bold" >this</span> <span id="hypo_gru_transformer_0_5" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_5&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_5&quot;)" style="color:#1A5276;font-weight:bold" >year</span> <span id="hypo_gru_transformer_0_6" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_6&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_6&quot;)" style="color:#1A5276;font-weight:bold" >,</span> <span id="hypo_gru_transformer_0_7" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_7&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_7&quot;)" style="color:#1A5276;font-weight:bold" >there</span> <span id="hypo_gru_transformer_0_8" >will</span> <span id="hypo_gru_transformer_0_9" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_9&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_9&quot;)" style="color:#1A5276;font-weight:bold" >be</span> <span id="hypo_gru_transformer_0_10" >about</span> <span id="hypo_gru_transformer_0_11" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_11&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_11&quot;)" style="color:#1A5276;font-weight:bold" >a</span> <span id="hypo_gru_transformer_0_12" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_12&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_12&quot;)" style="color:#1A5276;font-weight:bold" >billion</span> <span id="hypo_gru_transformer_0_13" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_13&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_13&quot;)" style="color:#1A5276;font-weight:bold" >people</span> <span id="hypo_gru_transformer_0_14" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_14&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_14&quot;)" style="color:#1A5276;font-weight:bold" >on</span> <span id="hypo_gru_transformer_0_15" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_15&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_15&quot;)" style="color:#1A5276;font-weight:bold" >this</span> <span id="hypo_gru_transformer_0_16" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_16&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_16&quot;)" style="color:#1A5276;font-weight:bold" >planet</span> <span id="hypo_gru_transformer_0_17" onmouseover="javascript:highlight_span(this, &quot;ref_0_0_18&quot;)" onmouseout="javascript:dehighlight_span(this, &quot;ref_0_0_18&quot;)" style="color:#1A5276;font-weight:bold" >actively</span> <span id="hypo_gru_transformer_0_18" >using</span> <span id="hyp
